# %%
############### Start of Error Handling####

# Reference the code block below.

# Which of these statements (try, except ZeroDivisionError, else, or finally) ALWAYS executes?

# Select all that apply

import random
try:
    5 / random.randint(0,5)
except ZeroDivisionError:
    print('Cannot divide by zero')
else:
    print('no errors detected')
finally:
    print('operations are complete')


# ANS: 
# try
# execute

# %%
#Which of the following is NOT an error in Python?

#Code Error

# %%
# Fill in the blank below to finish the code block.

def try_and_except(a,b):
    try: 
        return a + b
    
    except:
        
        return ("The Values must be int")
    
print(try_and_except("5", 5))

# except
# Out:
# The Values must be int

# %%
#Write a function that takes in a list and an index (number). 
# Using try and except, attempt to access the item in the list at that index number and see if the index is in the range. If it is, then return that item. 
# If it is out of range, return "INDEX NOT IN LIST". Use RETURN AND DO NOT PUT FUNCTION CALL IN ANSWER.


def func(li, i):
    try:                                       
        return li[i]
    except:
        return "INDEX NOT IN LIST"
    
# For this problem, think very simply about calling the function through a "return"

# %%
# True or False: When using try and except, one must also use finally. 

# False

# %%
# Complete the Python function to attempt division with the provided parameters. 
# The function should be able to handle an "ArithmeticError" exception if there is an arithmetic error. 

# If no error occurs, the function should print the answer of the division equation.

# If an error occurs print the following string: "Arithmetic error occurred!" 

# DO NOT PUT FUNCTION CALL IN ANSWER AND USE PRINT.

def division(dividend, divisor):							 

    try:
        result = dividend / divisor
        print(result)
    
    except (ArithmeticError, TypeError):
        print('Arithmetic error occurred!')
