# %%
# Use str with splicing and concatenation of two items to set result to the string ‘arch’.
str = 'flowchart'

result = str[6:8] + str[4:6]
result = str[-3:-1] + str[-5:-3]
result = str[6:8] + str[-5:-3]

# %%
"""
    Write the function pickFruit that has four parameters: a string named farm that is the
name of a fruit farm, an integer named apples that is the number of apples picked, an
integer named pears that is the number of pears picked, and an integer named limit that
is the max one can pick of an individual fruit. This function returns a string containing the
name of the farm, followed by a colon ”:”, followed by the string ”limit is ”, followed by the
value of limit, followed by a colon ”:”, followed by a message. If the person picked more than
limit apples and more than limit pears, the message is ”too many of both”. Otherwise, if
the person picked more than limit apples, the message is ”too many apples”. If the person
picked more than limit pears, the message is ”too many pears”. If none of those are true,
then the message is ”picked the right amount”. Here are some examples:
    
"""
def pickFruit(farm, limit, apples, pears):
    result = farm + ":limit is " + str(limit)+":"
    if apples >= limit and pears >= limit:
        return result + "too many of both"
    if apples >= limit:
        return result + "too many apples"
    if pears >= limit:
        return result + "too many pear# Define a function called myRange that takes a variable number of arguments, but no more than 3.  
# The function should return a list of integers that approximates the range function.  If the number of arguments is 1, 
# then the function should return a list of integers starting at 0 and increments by 1 up to one less than the argument. 
# If the number of arguments is 2, then the function should return a list of integers starting at the first argument and increments by 1 up to one less than the second argument.  
# If the number of arguments is 3, then the function should return a list of integers starting at the first argument and increments by
# the third argument going up to one less than the second argument.  
# If there are more than 4 arguments the function should return Too many arguments.
s"
    return result + "picked the right amount"

# %%
"""
    
    Use string str below with only join and split with appropriate small string constants to set
result to the value ‘melon*raisin*lemon*apple’
You can use temporary variable(s) if you want to write the code in more than one line.
str = "melonraisinlemonapple
"""

str = "melonraisinlemonapple"
temp = str.split("n")
result = "n*".join(temp)
#OR
result = "n*".join(str.split("n"))


"""
    Write the function chairs that has three parameters: an integer total that is the number of
chairs in a cafeteria, and two floats perc1 and perc2 that represent percentages. Some of
the chairs in the cafeteria need to be removed, perc1 percent of them are being removed for
repairs, and perc2 percent of them are being removed for an event in another room. This
function returns the number of chairs remaining after perc1 percent and perc2 percent of
the chairs have been removed. If the number to be removed is not an integer number then
truncate it. That is, if 2.8 percent of the chairs need to be removed for repairs, that means 2
chairs need to be removed. You can assume all the arguments for the three parameters are
greater than 0, and the two percentages total will not remove all the chairs
    
"""


def chairs(total, perc1, perc2):
    num1 = int(perc1 * total)
    num2 = int(perc2 * total)
    return total - num1 - num2

# %%
"""
Write the function compose that has four string parameters named word1, word2, word3,
and word4.
This function returns a string that is randomly one of word1 or word2, followed by randomly
one of word3 or word4.
Here are some examples (there are other possible return values not shown)
"""

def compose(word1, word2, word3, word4):
    num = random.randint(1,2)
    ans = ""
    if num == 1:
        ans = word1
    else:
        ans = word2
    num = random.randint(1, 2)
    if num == 1:
        ans = ans + " " + word3
    else:
        ans = ans + " " + word4
    return ans

# %%
"""
    You must use a for loop to solve this problem. Here is an example for loop that
returns the sum of the numbers in a list, so addlist([6, 2, 8]) returns 16.
def addlist(somelist):
    sum = 0
    for num in somelist:
    sum = sum + num
    return sum
Write the function named numsLarger that has two parameters: a list of integers named
lst, and an integer named largest. This function returns the number of integers in lst that
are larger than largest. Here are several examples of calls to this function. Complete the
function below.
    
"""
def numsLarger(lst, largest):
    count = 0
    for num in lst:
        if num > largest:
            count = count + 1
    return count

# or

def numsLarger(lst, largest):
    count = 0
    for num in lst:
        if num > largest:
            count += 1
    return count

# %%
"""
he variable result should calculate the list of words from lst that contain the string ’et’
in its middle (”et” cannot start the word, and the word cannot end with ”et”.) You can
assume all words in lst contain at least one letter. The words in result should appear in
the same order they appear in lst.
Using the list lst below, result would calculate the list: [’retro’, ’fetch’]
lst = [’etch’, ’caret’, ’retro’, ’ether’, ’cat’, ’fetch’, ’stern’]
result =
"""


result = [w for w in lst if 'et' in w[1:-1] ]


result = [w for w in lst if 'et' in w[1:len(w)-1] ]



result = [w for w in lst if 'et' in w and w[:2] != 'et' and w[-2:] != 'et']


result = [w for w in lst if 'et' in w and not w.startswith('et') and  not w.endswith('et')]

# %%
Given the string of words named phrase, calculate a list of tuples, where each tuple repre-
sents a word from phrase and has two items, 1) the first letter of the word and 2) the word
with the first letter of the word replaced by the last letter of the word. The tuple for each
word should appear in the same order the words appear in phrase. The answer should be
stored in the variable result.
Using the string phrase below, result’s value would be:
[(’r’, ’nun’), (’a’, ’a’), (’f’, ’wew’), (’m’, ’siles’), (’f’, ’ror’), (’e’,
’exercise’)]
Note the first word in phrase is ’run’, it’s first letter is ’r’, and the word with the first letter
of ’run’ replaced with the last letter of the word is ’nun’, resulting in the tuple (’r’, ’nun’).
Write your code below and be sure result’s value is the answer.
phrase = "run a few miles for exercise



result = [(w[0],w[-1]+w[1:]) for w in phrase.split()]

OR

result = []
for w in phrase.split():
    result.append((w[0],w[-1]+w[1:]))

OR

result = []
words = phrase.split()
for w in words:
    newword = w[-1] + w[1:]
    result.append((w[0], newword)

OR

result = []
words = phrase.split()
for w in words:
    if len(w) == 1:
       ans = (w,w)
     else:
        ans = (w[0], w[-1] + w[1:])
    result.append(ans)

# %%
Write the function named numberOrders that has two parameters. The first parameter
is named datalist, which is a list of lists in the format described earlier, and the second
parameter is a string named store representing the name of a store.
We repeat the format of datalist, a list of lists, with each inner list having the following
four items: 1) a string representing the name of a store, 2) a string representing the state
abbreviation where the store is located, 3) the price the store pays for the backpacks, as a
float and 4) a list of integers of orders of the backpack.
This function returns the total number of backpacks the store has ordered.
For example, assume datalist is the list of lists shown on the first page of this problem. We
give several examples of calls to this function


def numberOrders(datalist, store):
    for storeInfo in datalist:
        if store == storeInfo[0]:  #store matches
            return sum(storeInfo[-1])
    return 0

OR

def numberOrders(datalist, store):
    total = 0
    for storeInfo in datalist:
        if store == storeInfo[0]:  #store matches
            total += storeInfo[-1]
    return total

OR

#Note there is only one item in the list and you index into it to return that item. 
def numberOrders(datalist, store):
    return [sum(alist[-1]) for storeInfo in datalist if storeInfo[0] == store ][0]

# %%
Write the function named storesFromState that has two parameters. The first parameter
is named datalist, which is a list of lists in the format described earlier, and the second
parameter is a string named state.
We repeat the format of datalist, a list of lists, with each inner list having the following
four items: 1) a string representing the name of a store, 2) a string representing the state
abbreviation where the store is located, 3) the price the store pays for the backpacks, as a
float and 4) a list of integers of orders of the backpack.
This function returns a sorted list of stores from datalist that are in the specified state. We
give several examples of calls to this function.


def storesFromState(datalist, state):
    answer = []
    for storeInfo in datalist:
        if state == storeInfo[1]: # state matches
            answer.append(storeInfo[0])
    return sorted(answer)


OR

def storesFromState(datalist, state):
    answer = [storeInfo[0] for storeInfo in datalist if state == storeInfo[1] ]
    return sorted(answer)

# %%
NETID:
Part C (7 pts, 7 minutes)
Write the function named largestTotal that has one parameter named datalist, which is
a list of lists in the format described earlier.
We repeat the format of datalist, a list of lists, with each inner list having the following
four items: 1) a string representing the name of a store, 2) a string representing the state
abbreviation where the store is located, 3) the price the store pays for the backpacks, as a
float and 4) a list of integers of orders of the backpack.
This function returns the name of the store that has spent the most funds on these backpacks.
For example, assume datalist is the list on the first page of this problem, then the call
largestTotal(datalist) returns Minerva’s Things. This store bought 53 backpacks at
a cost of $5.29 per backpack, which was the largest amount spent from any store on these
backpacks

def largestTotal(datalist):
    maxTotal = 0
    maxPurch = ""
    for storeInfo in datalist:
        total = storeInfo[2]* sum(storeInfo[3])
        if total > maxTotal:
            maxTotal = total
            maxPurch = storeInfo[0]
    return maxPurch

# %%
myList = [[1,2,3], [4,5,6], [1,2,3,4], [9,10]]

lastLen = len(myList[-1])
firstLen = len(myList[0])
print(lastLen * firstLen)
# Out:
# 6

# %%
import logging
print(dir(logging))

# %%
def reverseit():
    user = input()
    lst[]
    while user:
        lst.append(user[::-1])
        user = input()
    return

# %%
#Great way to pull out the charaacter to get the item sinto a new list and print it.

fruits = ['apples', 'banana', 'cherry', 'kiwi', 'mango']
newlist = [x for x in fruits if "a" in x]
print(newlist)
# Out:
# ['apples', 'banana', 'mango']

# %%
def file_read(infile):
    with open (infile, 'w') as inf:
        for line in infile:
            print(line)

# %%
states = {'GA': 'Georgia', 'FL': 'Florida'}
for each_key, each_values in states.items():
    print(each_thing)
    print (each_key, each_values)
# Out:
# FL
# GA Georgia
# FL
# FL Florida

# %%
lottery = {'Mega Milllions': 1111111111}
sum = 0
for name, prize in lottery.items():
    sum = sum + prize
print(sum)
# Out:
# 1111111111

# %%
def v (vowels, word):
    words = words.lower()
    if any (v in words for v in vowels):
        return True
    else: 
        return False

# %%
Remember these for checking if something exists and what datatype
    
    isinstance()
    
    def x (obj):
        if isinstance(obj, float):
            return ("float")
        elif isinstance (obj, str):
            return ("string")
        else:
            return("unknown")

# %%
print(range(0,len(mySequence),2))

# %%
def BillSummary():
    total = 0.0
    while True:
        entry=input()
        if entry == "":
            break
        else:
            price = entry.split(' ')
            grand = total + price
        return f"{grandtotal:.2f}"

# %%
def BillSummary ():
    total = 0.0
    while True:
        line = input()
        if not line:
            break
        try:
            parts = line.split()
            cost_str= parts [1]
            cost = float(cost_str)
            total += cost
        except (IndexError, ValueError) as e:
            print (f'Invalid Input.')
    return total

# %%
#shoudl count the numbe rof times the lowercase letter "t" occurs in the variable good.  However, not matter how many t's I put in my test string and the most the functions returns is 1. 


#this is not good code:
    def iCanCount(good):
        for letter in good:
            count = 0
            if letter =='t':
                count +=1
            return count
